# %%
lis = [2,2,2,2,2,2,3]
sorted(set(lis))
# Out:
# [2, 3]

# %%
s = "wehiuhqfkjrwnhj"
list(s)
# Out:
# ['w', 'e', 'h', 'i', 'u', 'h', 'q', 'f', 'k', 'j', 'r', 'w', 'n', 'h', 'j']

# %%
import pandas as pd 
import json, requests

# %%
url = "https://data.nasa.gov/resource/y77d-th95.json"
resq = requests.get(url)

# %%
resq
# Out:
# <Response [200]>

# %%
data = pd.read_json("https://data.nasa.gov/resource/y77d-th95.json")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         1000 non-null   object
#  1   id                           1000 non-null   int64
#  2   nametype                     1000 non-null   object
#  3   recclass                     1000 non-null   object
#  4   mass                         972 non-null    float64
#  5   fall                         1000 non-null   object
#  6   year                         999 non-null    object
#  7   reclat                       988 non-null    float64
#  8   reclong                      988 non-null    float64
#  9   geolocation                  988 non-null    object
#  10  :@computed_region_cbhk_fwbd  133 non-null    float64
#  11  :@computed_region_nnqa_25f4  134 non-null    float64
# dtypes: float64(5), int64(1), object(6)
# ...

# %%
data = data.drop(["fall",":@computed_region_cbhk_fwbd",":@computed_region_nnqa_25f4"],axis=1)

# %%
data.head()
# Out:
#        name   id nametype     recclass      mass                     year  \
# 0    Aachen    1    Valid           L5      21.0  1880-01-01T00:00:00.000
# 1    Aarhus    2    Valid           H6     720.0  1951-01-01T00:00:00.000
# 2      Abee    6    Valid          EH4  107000.0  1952-01-01T00:00:00.000
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  1976-01-01T00:00:00.000
# 4   Achiras  370    Valid           L6     780.0  1902-01-01T00:00:00.000
#
#      reclat    reclong                                        geolocation
# 0  50.77500    6.08333  {'type': 'Point', 'coordinates': [6.08333, 50....
# 1  56.18333   10.23333  {'type': 'Point', 'coordinates': [10.23333, 56...
# 2  54.21667 -113.00000  {'type': 'Point', 'coordinates': [-113, 54.216...
# 3  16.88333  -99.90000  {'type': 'Point', 'coordinates': [-99.9, 16.88...
# 4 -33.16667  -64.95000  {'type': 'Point', 'coordinates': [-64.95, -33....

# %%
data["geolocation"].head()
# Out:
# 0    {'type': 'Point', 'coordinates': [6.08333, 50....
# 1    {'type': 'Point', 'coordinates': [10.23333, 56...
# 2    {'type': 'Point', 'coordinates': [-113, 54.216...
# 3    {'type': 'Point', 'coordinates': [-99.9, 16.88...
# 4    {'type': 'Point', 'coordinates': [-64.95, -33....
# Name: geolocation, dtype: object

# %%
data["geolocation"][0]["coordinates"]
# Out:
# [6.08333, 50.775]

# %%
for i in data['geolocation']:
    print(i)
# Out:
# {'type': 'Point', 'coordinates': [6.08333, 50.775]}
# {'type': 'Point', 'coordinates': [10.23333, 56.18333]}
# {'type': 'Point', 'coordinates': [-113, 54.21667]}
# {'type': 'Point', 'coordinates': [-99.9, 16.88333]}
# {'type': 'Point', 'coordinates': [-64.95, -33.16667]}
# {'type': 'Point', 'coordinates': [71.8, 32.1]}
# {'type': 'Point', 'coordinates': [95.16667, 44.83333]}
# {'type': 'Point', 'coordinates': [0.61667, 44.21667]}
# {'type': 'Point', 'coordinates': [-65.23333, -31.6]}
# {'type': 'Point', 'coordinates': [-64.55, -30.86667]}
# {'type': 'Point', 'coordinates': [-9.57028, 16.39806]}
# {'type': 'Point', 'coordinates': [8.38333, 19.08333]}
# {'type': 'Point', 'coordinates': [2.33333, 50.66667]}
# {'type': 'Point', 'coordinates': [35.05, 29.51667]}
# {'type': 'Point', 'coordinates': [77.95, 29.71667]}
# {'type': 'Point', 'coordinates': [8.43333, 8.91667]}
# {'type': 'Point', 'coordinates': [42.81667, 39.91667]}
# {'type': 'Point', 'coordinates': [39.51667, 24.41667]}
# ...

# %%
data = data.dropna()

# %%
data['geolocation'] = data['geolocation'].apply(lambda x: x['coordinates'])

# %%
data.head()
# Out:
#        name   id nametype     recclass      mass                     year  \
# 0    Aachen    1    Valid           L5      21.0  1880-01-01T00:00:00.000
# 1    Aarhus    2    Valid           H6     720.0  1951-01-01T00:00:00.000
# 2      Abee    6    Valid          EH4  107000.0  1952-01-01T00:00:00.000
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  1976-01-01T00:00:00.000
# 4   Achiras  370    Valid           L6     780.0  1902-01-01T00:00:00.000
#
#      reclat    reclong           geolocation
# 0  50.77500    6.08333     [6.08333, 50.775]
# 1  56.18333   10.23333  [10.23333, 56.18333]
# 2  54.21667 -113.00000      [-113, 54.21667]
# 3  16.88333  -99.90000     [-99.9, 16.88333]
# 4 -33.16667  -64.95000   [-64.95, -33.16667]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 959 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         959 non-null    object
#  1   id           959 non-null    int64
#  2   nametype     959 non-null    object
#  3   recclass     959 non-null    object
#  4   mass         959 non-null    float64
#  5   year         959 non-null    object
#  6   reclat       959 non-null    float64
#  7   reclong      959 non-null    float64
#  8   geolocation  959 non-null    object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 74.9+ KB

# %%
data.columns = ['Name of Earth Meteorite','ID of Earth Meteorite','nametype','recclass','mass','year','reclat','recclong','point coordinates']

# %%
data.head()
# Out:
#   Name of Earth Meteorite  ID of Earth Meteorite nametype     recclass  \
# 0                  Aachen                      1    Valid           L5
# 1                  Aarhus                      2    Valid           H6
# 2                    Abee                      6    Valid          EH4
# 3                Acapulco                     10    Valid  Acapulcoite
# 4                 Achiras                    370    Valid           L6
#
#        mass                     year    reclat   recclong  \
# 0      21.0  1880-01-01T00:00:00.000  50.77500    6.08333
# 1     720.0  1951-01-01T00:00:00.000  56.18333   10.23333
# 2  107000.0  1952-01-01T00:00:00.000  54.21667 -113.00000
# 3    1914.0  1976-01-01T00:00:00.000  16.88333  -99.90000
# 4     780.0  1902-01-01T00:00:00.000 -33.16667  -64.95000
#
#       point coordinates
# 0     [6.08333, 50.775]
# 1  [10.23333, 56.18333]
# 2      [-113, 54.21667]
# 3     [-99.9, 16.88333]
# 4   [-64.95, -33.16667]

# %%
data.to_csv("nasa.csv",header=True,index=False)

# %%
resp = requests.get("http://api.tvmaze.com/singlesearch/shows?q=westworld&embed=episodes")
data = resp.text

# %%
js_data = json.loads(data)

# %%
js_data
# Out:
# {'id': 1371,
#  'url': 'https://www.tvmaze.com/shows/1371/westworld',
#  'name': 'Westworld',
#  'type': 'Scripted',
#  'language': 'English',
#  'genres': ['Drama', 'Science-Fiction', 'Western'],
#  'status': 'Ended',
#  'runtime': 60,
#  'averageRuntime': 63,
#  'premiered': '2016-10-02',
#  'ended': '2022-08-14',
#  'officialSite': 'http://www.hbo.com/westworld',
#  'schedule': {'time': '21:00', 'days': ['Sunday']},
#  'rating': {'average': 8.2},
#  'weight': 99,
#  'network': {'id': 8,
#   'name': 'HBO',
#   'country': {'name': 'United States',
#    'code': 'US',
#    'timezone': 'America/New_York'},
#   'officialSite': 'https://www.hbo.com/'},
#  'webChannel': None,
#  'dvdCountry': None,
#  'externals': {'tvrage': 37537, 'thetvdb': 296762, 'imdb': 'tt0475784'},
#  'image': {'medium': 'https://static.tvmaze.com/uploads/images/medium_portrait/445/1113927.jpg',
#   'original': 'https://static.tvmaze.com/uploads/images/original_untouched/445/1113927.jpg'},
# ...

# %%
pd.DataFrame(js_data["network"])
# Out:
#           id name           country          officialSite
# code       8  HBO                US  https://www.hbo.com/
# name       8  HBO     United States  https://www.hbo.com/
# timezone   8  HBO  America/New_York  https://www.hbo.com/

# %%
pd.json_normalize(js_data)
# Out:
#      id                                          url       name      type  \
# 0  1371  https://www.tvmaze.com/shows/1371/westworld  Westworld  Scripted
#
#   language                             genres status  runtime  averageRuntime  \
# 0  English  [Drama, Science-Fiction, Western]  Ended       60              63
#
#     premiered  ... network.country.timezone  network.officialSite  \
# 0  2016-10-02  ...         America/New_York  https://www.hbo.com/
#
#    externals.tvrage externals.thetvdb externals.imdb  \
# 0             37537            296762      tt0475784
#
#                                         image.medium  \
# 0  https://static.tvmaze.com/uploads/images/mediu...
#
#                                       image.original  \
# 0  https://static.tvmaze.com/uploads/images/origi...
#
#                     _links.self.href              _links.previousepisode.href  \
# 0  https://api.tvmaze.com/shows/1371  https://api.tvmaze.com/episodes/2326661
#
# ...

# %%
data
# Out:
# '{"id":1371,"url":"https://www.tvmaze.com/shows/1371/westworld","name":"Westworld","type":"Scripted","language":"English","genres":["Drama","Science-Fiction","Western"],"status":"Ended","runtime":60,"averageRuntime":63,"premiered":"2016-10-02","ended":"2022-08-14","officialSite":"http://www.hbo.com/westworld","schedule":{"time":"21:00","days":["Sunday"]},"rating":{"average":8.2},"weight":99,"network":{"id":8,"name":"HBO","country":{"name":"United States","code":"US","timezone":"America/New_York"},"officialSite":"https://www.hbo.com/"},"webChannel":null,"dvdCountry":null,"externals":{"tvrage":37537,"thetvdb":296762,"imdb":"tt0475784"},"image":{"medium":"https://static.tvmaze.com/uploads/images/medium_portrait/445/1113927.jpg","original":"https://static.tvmaze.com/uploads/images/original_untouched/445/1113927.jpg"},"summary":"<p><b>Westworld</b> is a dark odyssey about the dawn of artificial consciousness and the evolution of sin. Set at the intersection of the near future and the reim
# ...

# %%
data = resp.json()

# %%
data.keys()
# Out:
# dict_keys(['id', 'url', 'name', 'type', 'language', 'genres', 'status', 'runtime', 'averageRuntime', 'premiered', 'ended', 'officialSite', 'schedule', 'rating', 'weight', 'network', 'webChannel', 'dvdCountry', 'externals', 'image', 'summary', 'updated', '_links', '_embedded'])

# %%
data_req = ['id', 'url', 'name', 'type','runtime', 'rating', '_embedded','image']
raw_data = {i:data[i] for i in data_req}

# %%
raw_data
# Out:
# {'id': 1371,
#  'url': 'https://www.tvmaze.com/shows/1371/westworld',
#  'name': 'Westworld',
#  'type': 'Scripted',
#  'runtime': 60,
#  'rating': {'average': 8.2},
#  '_embedded': {'episodes': [{'id': 869671,
#     'url': 'https://www.tvmaze.com/episodes/869671/westworld-1x01-the-original',
#     'name': 'The Original',
#     'season': 1,
#     'number': 1,
#     'type': 'regular',
#     'airdate': '2016-10-02',
#     'airtime': '21:00',
#     'airstamp': '2016-10-03T01:00:00+00:00',
#     'runtime': 68,
#     'rating': {'average': 8},
#     'image': {'medium': 'https://static.tvmaze.com/uploads/images/medium_landscape/78/195475.jpg',
#      'original': 'https://static.tvmaze.com/uploads/images/original_untouched/78/195475.jpg'},
# ...

# %%
pd.DataFrame(data['_embedded'])
# Out:
#                                              episodes
# 0   {'id': 869671, 'url': 'https://www.tvmaze.com/...
# 1   {'id': 911201, 'url': 'https://www.tvmaze.com/...
# 2   {'id': 911204, 'url': 'https://www.tvmaze.com/...
# 3   {'id': 911205, 'url': 'https://www.tvmaze.com/...
# 4   {'id': 927174, 'url': 'https://www.tvmaze.com/...
# 5   {'id': 932057, 'url': 'https://www.tvmaze.com/...
# 6   {'id': 938404, 'url': 'https://www.tvmaze.com/...
# 7   {'id': 943065, 'url': 'https://www.tvmaze.com/...
# 8   {'id': 943066, 'url': 'https://www.tvmaze.com/...
# 9   {'id': 943067, 'url': 'https://www.tvmaze.com/...
# 10  {'id': 1214222, 'url': 'https://www.tvmaze.com...
# 11  {'id': 1440915, 'url': 'https://www.tvmaze.com...
# 12  {'id': 1440916, 'url': 'https://www.tvmaze.com...
# 13  {'id': 1440917, 'url': 'https://www.tvmaze.com...
# 14  {'id': 1446362, 'url': 'https://www.tvmaze.com...
# 15  {'id': 1453278, 'url': 'https://www.tvmaze.com...
# ...

# %%
data['_embedded']['episodes']
# Out:
# [{'id': 869671,
#   'url': 'https://www.tvmaze.com/episodes/869671/westworld-1x01-the-original',
#   'name': 'The Original',
#   'season': 1,
#   'number': 1,
#   'type': 'regular',
#   'airdate': '2016-10-02',
#   'airtime': '21:00',
#   'airstamp': '2016-10-03T01:00:00+00:00',
#   'runtime': 68,
#   'rating': {'average': 8},
#   'image': {'medium': 'https://static.tvmaze.com/uploads/images/medium_landscape/78/195475.jpg',
#    'original': 'https://static.tvmaze.com/uploads/images/original_untouched/78/195475.jpg'},
#   'summary': "<p>A woman named Dolores is a free spirit in the Old West... and unaware that she's actually an android, programmed to entertain rich guests seeking to act out their fantasies in an idealized vision of the 1880s. However, the people in charge soon realize that their androids are acting in ways that they didn't anticipate.</p>",
#   '_links': {'self': {'href': 'https://api.tvmaze.com/episodes/869671'},
# ...

# %%
raw_data = pd.DataFrame(data['_embedded']['episodes'])
raw_data.head(1)
# Out:
#        id                                                url          name  \
# 0  869671  https://www.tvmaze.com/episodes/869671/westwor...  The Original
#
#    season  number     type     airdate airtime                   airstamp  \
# 0       1       1  regular  2016-10-02   21:00  2016-10-03T01:00:00+00:00
#
#    runtime          rating                                              image  \
# 0       68  {'average': 8}  {'medium': 'https://static.tvmaze.com/uploads/...
#
#                                              summary  \
# 0  <p>A woman named Dolores is a free spirit in t...
#
#                                               _links
# 0  {'self': {'href': 'https://api.tvmaze.com/epis...

# %%
req_dat = ['id','url','name','season','number','type','airdate','airtime','runtime','rating','summary','image']
unfin_data = raw_data[req_dat]
unfin_data.head()
# Out:
#        id                                                url  \
# 0  869671  https://www.tvmaze.com/episodes/869671/westwor...
# 1  911201  https://www.tvmaze.com/episodes/911201/westwor...
# 2  911204  https://www.tvmaze.com/episodes/911204/westwor...
# 3  911205  https://www.tvmaze.com/episodes/911205/westwor...
# 4  927174  https://www.tvmaze.com/episodes/927174/westwor...
#
#                 name  season  number     type     airdate airtime  runtime  \
# 0       The Original       1       1  regular  2016-10-02   21:00       68
# 1           Chestnut       1       2  regular  2016-10-09   21:00       60
# 2          The Stray       1       3  regular  2016-10-16   21:00       60
# 3  Dissonance Theory       1       4  regular  2016-10-23   21:00       60
# 4        Contrapasso       1       5  regular  2016-10-30   21:00       60
#
#              rating                                            summary  \
# 0    {'average': 8}  <p>A woman named Dolores is a free spirit in t...
# ...

# %%
unfin_data['average rating'] = unfin_data['rating'].apply(lambda x: x['average'])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_2084\1460125652.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unfin_data['average rating'] = unfin_data['rating'].apply(lambda x: x['average'])

# %%
unfin_data.drop('rating',axis=1,inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_2084\4244145941.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unfin_data.drop('rating',axis=1,inplace=True)

# %%
unfin_data['image'][0]
# Out:
# {'medium': 'https://static.tvmaze.com/uploads/images/medium_landscape/78/195475.jpg',
#  'original': 'https://static.tvmaze.com/uploads/images/original_untouched/78/195475.jpg'}

# %%
unfin_data['medium image link'] = unfin_data['image'].apply(lambda x: x['medium'])
unfin_data['Original image link'] = unfin_data['image'].apply(lambda x: x['original'])
unfin_data.drop('image',axis=1,inplace=True)
unfin_data.head()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_2084\3303708922.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unfin_data['medium image link'] = unfin_data['image'].apply(lambda x: x['medium'])
#        id                                                url  \
# 0  869671  https://www.tvmaze.com/episodes/869671/westwor...
# 1  911201  https://www.tvmaze.com/episodes/911201/westwor...
# 2  911204  https://www.tvmaze.com/episodes/911204/westwor...
# 3  911205  https://www.tvmaze.com/episodes/911205/westwor...
# 4  927174  https://www.tvmaze.com/episodes/927174/westwor...
#
#                 name  season  number     type     airdate airtime  runtime  \
# 0       The Original       1       1  regular  2016-10-02   21:00       68
# ...

# %%
unfin_data['summary'] = unfin_data['summary'].apply(lambda x: str(x))

# %%
unfin_data['summary'] = unfin_data['summary'].replace("<p>","")
unfin_data['summary'] = unfin_data['summary'].replace("</p>","")

# %%
unfin_data.head()
# Out:
#        id                                                url  \
# 0  869671  https://www.tvmaze.com/episodes/869671/westwor...
# 1  911201  https://www.tvmaze.com/episodes/911201/westwor...
# 2  911204  https://www.tvmaze.com/episodes/911204/westwor...
# 3  911205  https://www.tvmaze.com/episodes/911205/westwor...
# 4  927174  https://www.tvmaze.com/episodes/927174/westwor...
#
#                 name  season  number     type     airdate airtime  runtime  \
# 0       The Original       1       1  regular  2016-10-02   21:00       68
# 1           Chestnut       1       2  regular  2016-10-09   21:00       60
# 2          The Stray       1       3  regular  2016-10-16   21:00       60
# 3  Dissonance Theory       1       4  regular  2016-10-23   21:00       60
# 4        Contrapasso       1       5  regular  2016-10-30   21:00       60
#
#                                              summary  average rating  \
# 0  <p>A woman named Dolores is a free spirit in t...             8.0
# ...

# %%
def remove_html_tags(text):
    """Remove html tags from a string"""
    import re
    clean = re.compile('<.*?>')
    return re.sub(clean, '', text)

# %%
unfin_data['summary'] = unfin_data['summary'].apply(lambda x: remove_html_tags(x))

# %%
data = pd.read_csv("nasa.csv")

# %%
data.head()
# Out:
#   Name of Earth Meteorite  ID of Earth Meteorite nametype     recclass  \
# 0                  Aachen                      1    Valid           L5
# 1                  Aarhus                      2    Valid           H6
# 2                    Abee                      6    Valid          EH4
# 3                Acapulco                     10    Valid  Acapulcoite
# 4                 Achiras                    370    Valid           L6
#
#        mass                     year    reclat   recclong  \
# 0      21.0  1880-01-01T00:00:00.000  50.77500    6.08333
# 1     720.0  1951-01-01T00:00:00.000  56.18333   10.23333
# 2  107000.0  1952-01-01T00:00:00.000  54.21667 -113.00000
# 3    1914.0  1976-01-01T00:00:00.000  16.88333  -99.90000
# 4     780.0  1902-01-01T00:00:00.000 -33.16667  -64.95000
#
#       point coordinates
# 0     [6.08333, 50.775]
# 1  [10.23333, 56.18333]
# 2      [-113, 54.21667]
# 3     [-99.9, 16.88333]
# 4   [-64.95, -33.16667]

# %%
data['year'] = data['year'].apply(lambda x : int(str(x).split("-")[0]))

# %%
data[data['year']<2000]
# Out:
#     Name of Earth Meteorite  ID of Earth Meteorite nametype     recclass  \
# 0                    Aachen                      1    Valid           L5
# 1                    Aarhus                      2    Valid           H6
# 2                      Abee                      6    Valid          EH4
# 3                  Acapulco                     10    Valid  Acapulcoite
# 4                   Achiras                    370    Valid           L6
# ..                      ...                    ...      ...          ...
# 953                Timochin                  24004    Valid           H5
# 954                Tirupati                  24009    Valid           H6
# 956                   Tjabe                  24011    Valid           H6
# 957                Tjerebon                  24012    Valid           L5
# 958               Tomakovka                  24019    Valid          LL6
#
#          mass  year    reclat   recclong      point coordinates
# ...

# %%
data[data['mass']<1000]['Name of Earth Meteorite']
# Out:
# 0         Aachen
# 1         Aarhus
# 2           Abee
# 3       Acapulco
# 4        Achiras
#          ...
# 953     Timochin
# 954     Tirupati
# 956        Tjabe
# 957     Tjerebon
# 958    Tomakovka
# Name: Name of Earth Meteorite, Length: 893, dtype: object

# %%
data[data['mass']<1000]['Name of Earth Meteorite']
# Out:
# 0                   Aachen
# 1                   Aarhus
# 4                  Achiras
# 6      Adzhi-Bogdo (stone)
# 12                   Akaba
#               ...
# 935             Takenouchi
# 938                   Tané
# 946                   Thal
# 954               Tirupati
# 958              Tomakovka
# Name: Name of Earth Meteorite, Length: 293, dtype: object

# %%
data[data['mass']>10000]
# Out:
#     Name of Earth Meteorite  ID of Earth Meteorite nametype   recclass  \
# 2                      Abee                      6    Valid        EH4
# 7                      Agen                    392    Valid         H5
# 11                      Aïr                    424    Valid         L6
# 15                  Akyumak                    433    Valid  Iron, IVA
# 26               Alfianello                    466    Valid         L6
# ..                      ...                    ...      ...        ...
# 950               Tieschitz                  23989    Valid     H/L3.6
# 951                  Tilden                  23998    Valid         L6
# 953                Timochin                  24004    Valid         H5
# 956                   Tjabe                  24011    Valid         H6
# 957                Tjerebon                  24012    Valid         L5
#
#          mass  year    reclat   recclong      point coordinates
# ...

# %%
unfin_data.head(1)
# Out:
#        id                                                url          name  \
# 0  869671  https://www.tvmaze.com/episodes/869671/westwor...  The Original
#
#    season  number     type     airdate airtime  runtime  \
# 0       1       1  regular  2016-10-02   21:00       68
#
#                                              summary  average rating  \
# 0  A woman named Dolores is a free spirit in the ...             8.0
#
#                                    medium image link  \
# 0  https://static.tvmaze.com/uploads/images/mediu...
#
#                                  Original image link
# 0  https://static.tvmaze.com/uploads/images/origi...

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(unfin_data['season'],unfin_data['average rating'])
plt.
# Out:
# <BarContainer object of 36 artists>
